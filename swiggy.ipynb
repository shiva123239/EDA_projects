# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("swiggy[1].csv",delimiter=',')
data
# Out:
#           ID                    Area       City                Restaurant  \
# 0        211             Koramangala  Bangalore               Tandoor Hut
# 1        221             Koramangala  Bangalore             Tunday Kababi
# 2        246               Jogupalya  Bangalore                   Kim Lee
# 3        248             Indiranagar  Bangalore         New Punjabi Hotel
# 4        249             Indiranagar  Bangalore                       Nh8
# ...      ...                     ...        ...                       ...
# 8675  464626  Panjarapole Cross Road  Ahmedabad                Malt Pizza
# 8676  465835                  Rohini      Delhi  Jay Mata Ji Home Kitchen
# 8677  465872                  Rohini      Delhi      Chinese Kitchen King
# 8678  465990                  Rohini      Delhi    Shree Ram Paratha Wala
# 8679  466488             Navrangpura  Ahmedabad              Sassy Street
#
#       Price  Avg ratings  Total ratings  \
# ...

# %%
print(data.info())
print(data.describe)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8680 entries, 0 to 8679
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ID             8680 non-null   int64
#  1   Area           8680 non-null   object
#  2   City           8680 non-null   object
#  3   Restaurant     8680 non-null   object
#  4   Price          8680 non-null   float64
#  5   Avg ratings    8680 non-null   float64
#  6   Total ratings  8680 non-null   int64
#  7   Food type      8680 non-null   object
#  8   Address        8680 non-null   object
#  9   Delivery time  8680 non-null   int64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 678.3+ KB
# None
# <bound method NDFrame.describe of           ID                    Area       City                Restaurant  \
# 0        211             Koramangala  Bangalore               Tandoor Hut
# 1        221             Koramangala  Bangalore             Tunday Kababi
# ...

# %%
data.head()
# Out:
#     ID         Area       City         Restaurant  Price  Avg ratings  \
# 0  211  Koramangala  Bangalore        Tandoor Hut  300.0          4.4
# 1  221  Koramangala  Bangalore      Tunday Kababi  300.0          4.1
# 2  246    Jogupalya  Bangalore            Kim Lee  650.0          4.4
# 3  248  Indiranagar  Bangalore  New Punjabi Hotel  250.0          3.9
# 4  249  Indiranagar  Bangalore                Nh8  350.0          4.0
#
#    Total ratings                                          Food type  \
# 0            100          Biryani,Chinese,North Indian,South Indian
# 1            100                                   Mughlai,Lucknowi
# 2            100                                            Chinese
# 3            500               North Indian,Punjabi,Tandoor,Chinese
# 4             50  Rajasthani,Gujarati,North Indian,Snacks,Desser...
#
#         Address  Delivery time
# 0     5Th Block             59
# 1     5Th Block             56
# 2   Double Road             50
# ...

# %%
data.tail()
# Out:
#           ID                    Area       City                Restaurant  \
# 8675  464626  Panjarapole Cross Road  Ahmedabad                Malt Pizza
# 8676  465835                  Rohini      Delhi  Jay Mata Ji Home Kitchen
# 8677  465872                  Rohini      Delhi      Chinese Kitchen King
# 8678  465990                  Rohini      Delhi    Shree Ram Paratha Wala
# 8679  466488             Navrangpura  Ahmedabad              Sassy Street
#
#       Price  Avg ratings  Total ratings                   Food type  \
# 8675  500.0          2.9             80                      Pizzas
# 8676  200.0          2.9             80                South Indian
# 8677  150.0          2.9             80      Chinese,Snacks,Tandoor
# 8678  150.0          2.9             80  North Indian,Indian,Snacks
# 8679  250.0          2.9             80        Chaat,Snacks,Chinese
#
#           Address  Delivery time
# 8675  Navrangpura             40
# 8676       Rohini             28
# ...

# %%
data.isnull().sum
# Out:
# <bound method DataFrame.sum of          ID   Area   City  Restaurant  Price  Avg ratings  Total ratings  \
# 0     False  False  False       False  False        False          False
# 1     False  False  False       False  False        False          False
# 2     False  False  False       False  False        False          False
# 3     False  False  False       False  False        False          False
# 4     False  False  False       False  False        False          False
# ...     ...    ...    ...         ...    ...          ...            ...
# 8675  False  False  False       False  False        False          False
# 8676  False  False  False       False  False        False          False
# 8677  False  False  False       False  False        False          False
# 8678  False  False  False       False  False        False          False
# 8679  False  False  False       False  False        False          False
#
#       Food type  Address  Delivery time
# ...

# %%
data['Area'].unique()
# Out:
# array(['Koramangala', 'Jogupalya', 'Indiranagar', 'Domlur', 'Cooke Town',
#        'Pulikeshi Nagar', 'Sivanchetti Gardens', 'Kodihalli', 'Jayanagar',
#        'Film Nagar', 'Banashankari', 'Masab Tank', 'Banjara Hills',
#        'Andheri East', 'Powai', 'Punjagutta', 'Aundh', 'Baner',
#        'Powai Area', 'Ramgopalpet', 'Kalasiguda', 'Adarsh Nagar',
#        'Himayatnagar', 'Ashok Nagar', 'Commercial Street',
#        'Richmond Town', 'Vasanth Nagar', 'Bhowanipore', 'Ballygunge',
#        'Gariahat', 'Kalighat', 'Sion', 'Mumbai', 'Rajajinagar', 'Golpark',
#        'Shivajinagar', 'Koregaon Park', 'Deccan Gymkhana', 'Karkhana',
#        'Kothrud', 'Erandwane', 'Koti', 'Dilsukhnagar', 'Nagole',
#        'Chandrapuri Colony', 'Kothapet', 'Narayanguda', 'Fc Road',
#        'Park Street Area', 'Beniapukur', 'Bidhannagar', 'New Nallakunta',
#        'Adikmet', 'Amberpet', 'Karve Nagar', 'Agarkar Nagar', 'Mundhwa',
# ...

# %%
data['City'].unique()
# Out:
# array(['Bangalore', 'Hyderabad', 'Mumbai', 'Pune', 'Kolkata', 'Delhi',
#        'Chennai', 'Ahmedabad', 'Surat'], dtype=object)

# %%
Restaurants_listed_in_a_City=data.groupby('City')['Restaurant'].nunique()
Restaurants_listed_in_a_City
# Out:
# City
# Ahmedabad     709
# Bangalore     938
# Chennai      1096
# Delhi         611
# Hyderabad    1030
# Kolkata      1325
# Mumbai       1253
# Pune         1080
# Surat         505
# Name: Restaurant, dtype: int64

# %%
plt.figure(figsize=(8,8))
Restaurants_listed_in_a_City.plot(kind='bar',color='#40ff00')
plt.xticks(rotation = 360)
plt.ylabel('Number of Restaurants')
plt.title('Restaurants listed in each City',fontsize=14)
plt.show()

# %%
Avarage_order_Amount=data.groupby('City')['Price'].mean().sort_values(ascending=False)
Avarage_order_Amount
# Out:
# City
# Mumbai       393.794832
# Bangalore    382.524313
# Kolkata      362.294205
# Chennai      356.247740
# Pune         353.763303
# Delhi        333.301146
# Ahmedabad    318.128312
# Hyderabad    299.926512
# Surat        270.171875
# Name: Price, dtype: float64

# %%
plt.figure(figsize=(9,4))
Avarage_order_Amount.plot(kind = 'bar',color='pink')
plt.xticks(rotation = 360)
plt.ylabel('Avarage Order Price')
plt.title('City Avarage Order Amount',fontsize = 12)
plt.show()

# %%
Min_delivery_time= data.groupby(['Food type','Restaurant'])['Delivery time'].min().sort_values().head(20)
Min_delivery_time
# Out:
# Food type                                                              Restaurant
# Ice Cream,Desserts,Beverages                                           Scoops                                                    20
# Indian,Chinese                                                         Wah Ji Wah ( Budhvihar)                                   21
# Beverages,Chinese,Punjabi                                              Sarvottam Restaurant                                      22
# Haleem,Arabian,Biryani,Tandoor,Chinese,Indian,Desserts,Kebabs,Mughlai  Hotel Niagara                                             23
# Ice Cream,Desserts                                                     Nic Natural Ice Creams                                    23
# Desserts  Ice Cream  Chaat                                             Scoops                                                    24
# ...

# %%
plt.figure(figsize=(9,6))
Min_delivery_time.plot(kind='barh')
plt.xlabel('Time taken to delivery')
plt.show()

# %%
Max_delivery_time= data.groupby(['Food type','Restaurant'])['Delivery time'].max().sort_values(ascending=False).head(20)
Max_delivery_time
# Out:
# Food type                                            Restaurant
# Indian                                               Heavens Kitchen                   109
# Chinese,Desserts                                     Yin Yang - Pan Asian Delicacy     100
# Chinese,Pastas                                       Tamang'S Frozen Momo               98
# Fast Food                                            Sandwizz                           98
# Chinese                                              Fatty Mamma Chinese Restaurant     98
# Indian                                               Dastaan                            98
# North Indian                                         Shree Ganesh Home Kitchen          98
# Indian,Rajasthani,Punjabi,Thalis,Desserts,Beverages  Nisha'S Veg Kitchen                97
# Chinese,Seafood                                      Red Chilli Restaurant              97
# North Indian                                         Me & U                             97
# ...

# %%
plt.figure(figsize=(9,6))
Max_delivery_time.plot(kind='barh')
plt.xlabel('Time Taken to delivery')
plt.show()

# %%
data
# Out:
#           ID                    Area       City                Restaurant  \
# 0        211             Koramangala  Bangalore               Tandoor Hut
# 1        221             Koramangala  Bangalore             Tunday Kababi
# 2        246               Jogupalya  Bangalore                   Kim Lee
# 3        248             Indiranagar  Bangalore         New Punjabi Hotel
# 4        249             Indiranagar  Bangalore                       Nh8
# ...      ...                     ...        ...                       ...
# 8675  464626  Panjarapole Cross Road  Ahmedabad                Malt Pizza
# 8676  465835                  Rohini      Delhi  Jay Mata Ji Home Kitchen
# 8677  465872                  Rohini      Delhi      Chinese Kitchen King
# 8678  465990                  Rohini      Delhi    Shree Ram Paratha Wala
# 8679  466488             Navrangpura  Ahmedabad              Sassy Street
#
#       Price  Avg ratings  Total ratings  \
# ...

# %%
m=data.groupby('City')['Avg ratings'].mean().sort_values(ascending=False)
m
# Out:
# City
# Chennai      3.776311
# Bangalore    3.762896
# Hyderabad    3.701395
# Kolkata      3.698811
# Mumbai       3.599374
# Ahmedabad    3.596513
# Surat        3.580078
# Pune         3.550183
# Delhi        3.526350
# Name: Avg ratings, dtype: float64

# %%
plt.figure(figsize=(10,8))
m.plot(kind='line',color = 'blue')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
Bangalore_Area=data[(data['City'] == 'Bangalore')]['Area'].value_counts().sort_values(ascending=False).head(1)
Bangalore_Area
# Out:
# Area
# Indiranagar    130
# Name: count, dtype: int64

# %%
Ahmedabad_Area=data[(data['City'] == 'Ahmedabad')]['Area'].value_counts().sort_values(ascending=False).head(1)
Ahmedabad_Area
# Out:
# Area
# Navrangpura    132
# Name: count, dtype: int64

# %%
Surat_Area=data[(data['City'] == 'Surat')]['Area'].value_counts().sort_values(ascending=False).head(1)
Surat_Area
# Out:
# Area
# Athwa    99
# Name: count, dtype: int64

# %%
Delhi_Area=data[(data['City'] == 'Delhi')]['Area'].value_counts().sort_values(ascending=False).head(1)
Delhi_Area
# Out:
# Area
# Rohini    257
# Name: count, dtype: int64

# %%
Mumbai_Area=data[(data['City'] == 'Mumbai')]['Area'].value_counts().sort_values(ascending=False).head(1)
Mumbai_Area
# Out:
# Area
# Chembur    208
# Name: count, dtype: int64

# %%
Hyderabad_Area=data[(data['City'] == 'Hyderabad')]['Area'].value_counts().sort_values(ascending=False).head(1)
Hyderabad_Area
# Out:
# Area
# Banjara Hills    113
# Name: count, dtype: int64

# %%
Kolkata_Area=data[(data['City'] == 'Kolkata')]['Area'].value_counts().sort_values(ascending=False).head(1)
Kolkata_Area
# Out:
# Area
# Bidhannagar    123
# Name: count, dtype: int64

# %%
Chennai_Area=data[(data['City'] == 'Chennai')]['Area'].value_counts().sort_values(ascending=False).head(1)
Chennai_Area
# Out:
# Area
# Perambur    89
# Name: count, dtype: int64

# %%
Pune_Area=data[(data['City'] == 'Pune')]['Area'].value_counts().sort_values(ascending=False).head(1)
Pune_Area
# Out:
# Area
# Kothrud    149
# Name: count, dtype: int64

# %%
area=['Hyderabad-Banjara Hills','Pune-Kothrud','Ahmedabad-Navrangpura','Surat-Athwa','Delhi-Rohini','Bangalore-Indiranagar','Mumbai-Chembur',
      'Kolkata-Bidhannagar','Chennai-Perambur','Pune-Kothrud']



orders=[Hyderabad_Area.values[0],Pune_Area.values[0],Ahmedabad_Area.values[0],Surat_Area.values[0],Delhi_Area.values[0],Bangalore_Area.values[0],
        Mumbai_Area.values[0],Kolkata_Area.values[0],Chennai_Area.values[0],Pune_Area.values[0]]


colors=['#f90606','#996666','#808080','#ffb3b3','#ff1a1a','#1a0000','#ffe6e6','#E2EAF4','#CC6CE7','#BFD641']

plt.figure(figsize=(12, 8))
plt.pie(orders, labels=area, autopct='%.2f%%', colors= colors)
plt.title('Maximum Order Area for Each City')
plt.show()

# %%
Pune_Restaurant=data[(data['City'] == 'Pune')]
Pune_Restaurant


# HAR = Highest Average Rating
Pune_Restaurant_HAR= Pune_Restaurant.groupby('Restaurant')['Avg ratings'].mean().sort_values(ascending= False).head()
Pune_Restaurant_HAR
# Out:
# Restaurant
# Shree Krishna Juice Bar    5.0
# Papacream                  5.0
# Gulp                       4.9
# Rosso Bianco               4.8
# Arun Ice Creams            4.8
# Name: Avg ratings, dtype: float64

# %%
Mumbai_Restaurant=data[(data['City'] == 'Mumbai')]
Mumbai_Restaurant


Mumbai_Restaurant_HAR= Mumbai_Restaurant.groupby('Restaurant')['Avg ratings'].mean().sort_values(ascending= False).head()
Mumbai_Restaurant_HAR
# Out:
# Restaurant
# Diamond Market Pizza Jp    5.0
# Cafe Kokomo                5.0
# Get In My Belly            5.0
# Nivala Apka Apna           5.0
# The Asian Pavilion         5.0
# Name: Avg ratings, dtype: float64

# %%
Delhi_Restaurant=data[(data['City'] == 'Delhi')]
Delhi_Restaurant



Delhi_Restaurant_HAR= Delhi_Restaurant.groupby('Restaurant')['Avg ratings'].mean().sort_values(ascending= False).head()
Delhi_Restaurant_HAR
# Out:
# Restaurant
# Fat Tiger                                5.0
# Pizza Paradise By Vhc                    4.8
# Biryani By Kilo                          4.8
# The Sugar Free Keto Kafe - By Artinci    4.8
# Wok On Fire                              4.7
# Name: Avg ratings, dtype: float64

# %%
Kolkata_Restaurant=data[(data['City'] == 'Kolkata')]
Kolkata_Restaurant



Kolkata_Restaurant_HAR= Kolkata_Restaurant.groupby('Restaurant')['Avg ratings'].mean().sort_values(ascending= False).head()
Kolkata_Restaurant_HAR
# Out:
# Restaurant
# Keventers Ice Creamery                     5.0
# Pabrai'S Fresh And Naturelle Icecream      4.9
# Pabrai'S Fresh And Naturelle Ice Creams    4.8
# What'S Your Flavour?                       4.8
# Natural Ice Cream                          4.8
# Name: Avg ratings, dtype: float64

# %%
Surat_Restaurant=data[(data['City'] == 'Surat')]
Surat_Restaurant



Surat_Restaurant_HAR= Surat_Restaurant.groupby('Restaurant')['Avg ratings'].mean().sort_values(ascending= False).head()
Surat_Restaurant_HAR
# Out:
# Restaurant
# Sobis Diet Farm               4.8
# Kudrati Kahumbo               4.8
# The Pancake Story             4.8
# The Bungalow Cafe             4.7
# Amardeep Icecream & Juices    4.7
# Name: Avg ratings, dtype: float64

# %%
Ahmedabad_Restaurant=data[(data['City'] == 'Ahmedabad')]
Ahmedabad_Restaurant



Ahmedabad_Restaurant_HAR=Ahmedabad_Restaurant.groupby('Restaurant')['Avg ratings'].mean().sort_values(ascending= False).head()
Ahmedabad_Restaurant_HAR
# Out:
# Restaurant
# Natural Ice Cream                         4.8
# Ching Chong Chinese                       4.8
# Wok On Fire - Indo Chinese - Pan Asian    4.8
# Chup Chaap                                4.8
# Puffing - The Live Puff                   4.7
# Name: Avg ratings, dtype: float64

# %%
Chennai_Restaurant=data[(data['City'] == 'Chennai')]
Chennai_Restaurant


Chennai_Restaurant_HAR= Chennai_Restaurant.groupby('Restaurant')['Avg ratings'].mean().sort_values(ascending= False).head()
Chennai_Restaurant_HAR
# Out:
# Restaurant
# Afresh             5.00
# 1By2               4.90
# Milkie Mustache    4.90
# Ricky'S Cookies    4.90
# Nasi And Mee       4.75
# Name: Avg ratings, dtype: float64

# %%
Bangalore_Restaurant=data[(data['City'] == 'Bangalore')]
Bangalore_Restaurant



Bangalore_Restaurant_HAR= Bangalore_Restaurant.groupby('Restaurant')['Avg ratings'].mean().sort_values(ascending= False).head()
Bangalore_Restaurant_HAR
# Out:
# Restaurant
# Tricky Shakes             5.0
# Creams & Bites            5.0
# Frosty Crumble            4.9
# Royce' Chocolate          4.9
# Keventers Ice Creamery    4.9
# Name: Avg ratings, dtype: float64

# %%
Hyderabad_Restaurant=data[(data['City'] == 'Hyderabad')]
Hyderabad_Restaurant



Hyderabad_Restaurant_HAR= Hyderabad_Restaurant.groupby('Restaurant')['Avg ratings'].mean().sort_values(ascending= False).head()
Hyderabad_Restaurant_HAR
# Out:
# Restaurant
# Splurge - Thickshakes And Milkshakes    5.0
# Wallonia Waffle Co.                     5.0
# The Liege Waffles                       5.0
# Zorro - Milkshakes And Thickshakes      5.0
# Snack House                             4.9
# Name: Avg ratings, dtype: float64
